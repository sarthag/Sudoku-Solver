# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline
from Extract_Sudoku import *

# %%
img1 = 'Sudoku Images/Sudoku.jpeg'
img2 = 'Sudoku Images/Sudoku2.jpg'
img3 = 'Sudoku Images/Sudoku3.jpg'
img4 = 'Sudoku Images/Sudoku4.jpg'

# %%
sudoku1 = extract_sudoku(img1)
plt.imshow(sudoku1)

# %%
digits = get_digits(sudoku1)
for i in range(9):
    for j in range(9):
        digit = digits[i][j]
        plt.imshow(digit, cmap = "gray")
        plt.show()

# %%
sudoku2 = extract_sudoku(img2)
plt.imshow(sudoku2)

# %%
digits = get_digits(sudoku2)
for i in range(9):
    for j in range(9):
        digit = digits[i][j]
        plt.imshow(digit, cmap = "gray")
        plt.show()

# %%
sudoku3 = extract_sudoku(img3)
plt.imshow(sudoku3)

# %%
digits = get_digits(sudoku3)
for i in range(9):
    for j in range(9):
        digit = digits[i][j]
        plt.imshow(digit, cmap = "gray")
        plt.show()

# %%
sudoku4 = extract_sudoku(img4)
plt.imshow(sudoku4)

# %%
digits = get_digits(sudoku4)
for i in range(9):
    for j in range(9):
        digit = digits[i][j]
        plt.imshow(digit, cmap = "gray")
        plt.show()
