# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline
from Extract_Sudoku import extract_sudoku

# %%
img1 = 'Sudoku Images/Sudoku.jpeg'
img2 = 'Sudoku Images/Sudoku2.jpg'
img3 = 'Sudoku Images/Sudoku3.jpg'

# %%
sudoku1 = extract_sudoku(img1)
plt.imshow(sudoku1)

# %%
sudoku2 = extract_sudoku(img2)
plt.imshow(sudoku2)

# %%
sudoku3 = extract_sudoku(img3)
plt.imshow(sudoku3)
