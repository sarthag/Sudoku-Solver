# %%
import numpy as np
from Solve_Extracted import *
from Solver.print_grid import print_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = 'Sudoku Images/Sudoku.jpeg'
img2 = 'Sudoku Images/Sudoku2.jpg'
img3 = 'Sudoku Images/Sudoku3.jpg'
img4 = 'Sudoku Images/Sudoku4.jpg'
img5 = 'Sudoku Images/Sudoku5.jpg'

# %%
plt.imshow(extract_sudoku(img1))

# %%
solved = solve_sudoku(img1)
plt.imshow(place_digits(solved))

# %%
plt.imshow(extract_sudoku(img2))

# %%
solved = solve_sudoku(img2)
plt.imshow(place_digits(solved))

# %%
plt.imshow(extract_sudoku(img3))

# %%
solved = solve_sudoku(img3)
plt.imshow(place_digits(solved))

# %%
plt.imshow(extract_sudoku(img4))

# %%
solved = solve_sudoku(img4)
plt.imshow(place_digits(solved))

# %%
plt.imshow(extract_sudoku(img5))

# %%
solved = solve_sudoku(img5)
plt.imshow(place_digits(solved))
